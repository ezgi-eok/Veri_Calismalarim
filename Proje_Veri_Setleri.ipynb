# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action = "ignore", category = RuntimeWarning)

# %%
df = pd.read_csv('C:/Users/Acer/Desktop/Veri Seti/EdStatsEXCEL.csv')
df1 = pd.read_csv('C:/Users/Acer/Desktop/Veri Seti/EdStatsSeries.csv')
df2 = pd.read_csv('C:/Users/Acer/Desktop/Veri Seti/EdStatsCountry.csv')
df3 = pd.read_csv('C:/Users/Acer/Desktop/Veri Seti/EdStatsCountry-Series.csv')
df4 = pd.read_csv('C:/Users/Acer/Desktop/Veri Seti/EdStatsData.csv')
df5 = pd.read_csv('C:/Users/Acer/Desktop/Veri Seti/EdStatsFootNote.csv')
print(df.head())
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2055  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
df.tail()
df1.tail()
df2.tail()
df3.tail()
df4.tail()
df5.tail()
# Out:
#        CountryCode   SeriesCode    Year  \
# 643633         ZWE  SH.DYN.MORT  YR2007
# 643634         ZWE  SH.DYN.MORT  YR2014
# 643635         ZWE  SH.DYN.MORT  YR2015
# 643636         ZWE  SH.DYN.MORT  YR2017
# 643637         ZWE  SP.POP.GROW  YR2017
#
#                                    DESCRIPTION  Unnamed: 4
# 643633       Uncertainty bound is 91.6 - 109.3         NaN
# 643634          Uncertainty bound is 54.3 - 76         NaN
# 643635        Uncertainty bound is 48.3 - 73.3         NaN
# 643636  5-year average value between 0s and 5s         NaN
# 643637  5-year average value between 0s and 5s         NaN

# %%
def check_df(df):
    print(df.info())
    print('**********')
    print(df.describe().T)
    print('**********')
    print(df.isnull().sum())
    print('**********')
    print(df.shape)
    print('**********')
    print(df.size)
    print('**********')
    print(df.nunique())
    print('**********')

def check_df(df1):
    print(df1.info())
    print('**********')
    print(df1.describe().T)
    print('**********')
    print(df1.isnull().sum())
    print('**********')
    print(df1.shape)
    print('**********')
    print(df1.size)
    print('**********')
    print(df1.nunique())
    print('**********')

def check_df(df2):
    print(df2.info())
    print('**********')
    print(df2.describe().T)
    print('**********')
    print(df2.isnull().sum())
    print('**********')
    print(df2.shape)
    print('**********')
    print(df2.size)
    print('**********')
    print(df2.nunique())
    print('**********')

def check_df(df3):
    print(df3.info())
    print('**********')
    print(df3.describe().T)
    print('**********')
    print(df3.isnull().sum())
    print('**********')
    print(df3.shape)
    print('**********')
    print(df3.size)
    print('**********')
    print(df3.nunique())
    print('**********')

def check_df(df4):
    print(df4.info())
    print('**********')
    print(df4.describe().T)
    print('**********')
    print(df4.isnull().sum())
    print('**********')
    print(df4.shape)
    print('**********')
    print(df4.size)
    print('**********')
    print(df4.nunique())
    print('**********')

def check_df(df5):
    print(df5.info())
    print('**********')
    print(df5.describe().T)
    print('**********')
    print(df5.isnull().sum())
    print('**********')
    print(df5.shape)
    print('**********')
    print(df5.size)
    print('**********')
    print(df5.nunique())
    print('**********')

check_df(df)
check_df(df1)
check_df(df2)
check_df(df3)
check_df(df4)
check_df(df5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 69 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100'],
#       dtype='object')

# %%
years = [str(year) for year in range(1970, 2100)]
available_years = [year for year in years if year in df.columns]

# Melt işlemini mevcut yıllarla yapalım
df_melted = pd.melt(df, 
                    id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
                    value_vars=available_years, 
                    var_name='Year', 
                    value_name='Value')

# Sonuçları kontrol edelim
print(df_melted.head())
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  Year  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2  1970
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F  1970
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI  1970
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M  1970
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR  1970
#
#        Value
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4  54.822121

# %%
# Benzersiz değerleri görüntüle
print(df[['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']].drop_duplicates())

# 'Unit of measure' sütunundaki değerlerin sayısını görüntüle
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0       Adjusted net enrolment rate, lower secondary, ...
# 1       Adjusted net enrolment rate, lower secondary, ...
# 2       Adjusted net enrolment rate, lower secondary, ...
# 3       Adjusted net enrolment rate, lower secondary, ...
# 4       Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 886925  Youth illiterate population, 15-24 years, male...
# 886926  Youth literacy rate, population 15-24 years, b...
# ...

# %%
grouped = df.groupby(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])
print(grouped)
years_in_data = [col for col in df.columns if col.isdigit()]  # Yalnızca sayısal yılları al
print(years_in_data)
df_melted = pd.melt(df, 
                    id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
                    value_vars=years_in_data, var_name='Year', value_name='Value')
print(df_melted.head())
# Out:
# ...
# ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045', '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090', '2095', '2100']
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  Year  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2  1970
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F  1970
# ...

# %%
df_melted = pd.melt(df, 
                    id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
                    value_vars=years_in_data, var_name='Year', value_name='Value')
print(df_melted.head())
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  Year  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2  1970
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F  1970
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI  1970
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M  1970
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR  1970
#
#        Value
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4  54.822121

# %%
years_in_data = [col for col in df.columns if col.isdigit()]
df_melted = pd.melt(df, 
                    id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
                    value_vars=years_in_data, 
                    var_name='Year', 
                    value_name='Value')

# Yıllara göre toplam değerleri gruplama
yearly_data_sorted = yearly_data.sort_values(by='Value', ascending=False)

# Bar grafiği oluşturma
plt.figure(figsize=(12, 8))
sns.barplot(x='Year', y='Value', data=yearly_data_sorted, palette='viridis')

# Başlık ve etiketler
plt.title('Yıllık Verilerin Toplamı (Bar Grafik)', fontsize=15)
plt.xlabel('Yıl', fontsize=12)
plt.ylabel('Toplam Değer', fontsize=12)
plt.xticks(rotation=45)  # X eksenindeki yıl etiketlerini döndürme

plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15116\3104363755.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y='Value', data=yearly_data_sorted, palette='viridis')

# %%
# Dağılım grafiği oluşturma
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Year', y='Value', data=yearly_data_sorted, color='g', s=100)

# Başlık ve etiketler
plt.title('Yıllık Verilerin Dağılımı (Scatter Grafik)', fontsize=15)
plt.xlabel('Yıl', fontsize=12)
plt.ylabel('Toplam Değer', fontsize=12)

plt.xticks(rotation=45)  # Yıl etiketlerini döndürme
plt.grid(True)

plt.show()

# %%
# Çizgi grafiği oluşturma
plt.figure(figsize=(12, 8))
sns.lineplot(x='Year', y='Value', data=yearly_data_sorted, marker='o', color='b')

# Başlık ve etiketler
plt.title('Yıllık Verilerin Değişimi (Çizgi Grafik)', fontsize=15)
plt.xlabel('Yıl', fontsize=12)
plt.ylabel('Toplam Değer', fontsize=12)

plt.xticks(rotation=45)  # Yıl etiketlerini döndürme
plt.grid(True)

plt.show()

# %%
# Kutu grafiği oluşturma
plt.figure(figsize=(12, 8))
sns.boxplot(x='Year', y='Value', data=df_melted, palette='coolwarm')

# Başlık ve etiketler
plt.title('Yıllık Verilerin Dağılımı (Boxplot)', fontsize=15)
plt.xlabel('Yıl', fontsize=12)
plt.ylabel('Değer', fontsize=12)

plt.xticks(rotation=45)  # Yıl etiketlerini döndürme

plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15116\2318678945.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Year', y='Value', data=df_melted, palette='coolwarm')

# %%
# Yıllara göre verileri pivotlayalım
heatmap_data = df_melted.pivot_table(index='Country Name', columns='Year', values='Value', aggfunc='sum')

# Isı haritası oluşturma
plt.figure(figsize=(14, 10))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=False, fmt='g', linewidths=0.5)

# Başlık ve etiketler
plt.title('Yıllık Verilerin Isı Haritası', fontsize=15)
plt.xlabel('Yıl', fontsize=12)
plt.ylabel('Ülke', fontsize=12)

plt.show()
